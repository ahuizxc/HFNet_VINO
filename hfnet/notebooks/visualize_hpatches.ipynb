# %%
import cv2
import numpy as np
from pathlib import Path
from hfnet.datasets.hpatches import Hpatches
from utils import plot_images

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
config = {'make_pairs': True, 'shuffle': True} 
dataset = Hpatches(**config)
data = dataset.get_test_set()

# %%
for _ in range(3):
    d = next(data)
    plot_images([d['image'][:, :, 0], d['image2'][:, :, 0]],
                ylabel=d['name'].decode('utf-8'))
